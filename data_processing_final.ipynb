# %%
import json
import pandas as pd
import csv

# %%
raw_data = []
with open('final_raw_data_full.json') as d:
  raw_data = json.load(d)

print(len(raw_data))
# Out:
# 4603

# %%
blacklist_keywords = ['Christmas and Thanksgiving', "Saint Patrick's Day", "New Year's Eve", "Romantic and Valentine's Day", "Halloween", "4th July and Independence Day", "Hall of Fame and must know/try", "Modern", "Classic/vintage", "Contemporary classic", "Party", "Barbeque", "Tennis and Wimbledon", "Breakfast/brunch", "Elevenses/afternoon", "Anytime", "After dinner/digestif", "Summer", "Winter", "Autumn/fall", "Spring", "Layered", "Frappé", "Hot Drinks", "Sugar-free and low-calorie", "Shot cocktails", "Frozen (blended)", "Champagne", "Martini-style", "Long drinks and highballs", "Short and stirred", "Nightcap/sipping", "Spirit-forward", "Aperitivo/aperitif"]
filtered_raw_data = []
for dat in raw_data:
    obj = {}
    if 'ingridients' in dat:
        obj['ingridients'] = dat['ingridients']
    if 'keywords' in dat:
        keys = []
        for k in dat['keywords']:
            if k not in blacklist_keywords:
                if '(e.g.' in k:
                    k = k.split('(e.g')[0].strip()
                keys.append(k)
        obj['keywords'] = keys
    if 'strength_rating' in dat:
        obj['strength_rating'] = int(dat['strength_rating'].replace('Strength', '').replace('/10', ''))
    if 'taste_rating' in dat:
        obj['taste_rating'] = int(dat['taste_rating'].replace('Sweet to sour ', '').replace('/10', ''))
    if 'rating_data' in dat:
        obj['rating'] = dat['rating_data']['ratingValue']
    filtered_raw_data.append(obj)

print(len(filtered_raw_data))
# Out:
# 4603

# %%
def extractData(ingridient, keyword):
    if keyword in ingridient:
        splitted = ingridient.split(keyword)
        return [splitted[1].strip().lower(), float(splitted[0].strip()), keyword.strip()]

others = []
for dat in filtered_raw_data:
    ingridients = []
    for ingridient in dat['ingridients']:
        if ' ml ' in ingridient:
            ingridients.append(extractData(ingridient, ' ml '))
        elif ' dash ' in ingridient:
            ingridients.append(extractData(ingridient, ' dash '))
        elif ' pint ' in ingridient:
            ingridients.append(extractData(ingridient, ' pint '))
        elif ' drop ' in ingridient:
            ingridients.append(extractData(ingridient, ' drop '))
        elif ' fresh ' in ingridient:
            ingridients.append(extractData(ingridient, ' fresh '))
        elif ' barspoon ' in ingridient:
            ingridients.append(extractData(ingridient, ' barspoon '))
        elif ' pinch ' in ingridient:
            ingridients.append(extractData(ingridient, ' pinch '))
        elif ' sprig ' in ingridient:
            ingridients.append(extractData(ingridient, ' sprig '))
        elif ' swath ' in ingridient:
            ingridients.append(extractData(ingridient, ' swath '))
        elif ' dried ' in ingridient:
            ingridients.append(extractData(ingridient, ' dried '))
        elif ' slice ' in ingridient:
            ingridients.append(extractData(ingridient, ' slice '))
        elif ' grind ' in ingridient:
            ingridients.append(extractData(ingridient, ' grind '))
        elif ' wedge ' in ingridient:
            ingridients.append(extractData(ingridient, ' wedge '))
        elif ' whole ' in ingridient:
            ingridients.append(extractData(ingridient, ' whole '))
        elif ' twist ' in ingridient:
            ingridients.append(extractData(ingridient, ' twist '))
        elif ' ring ' in ingridient:
            ingridients.append(extractData(ingridient, ' ring '))
        elif ' inch ' in ingridient:
            ingridients.append(extractData(ingridient, ' inch '))
        elif ' cube ' in ingridient:
            ingridients.append(extractData(ingridient, ' cube '))
        elif ' pea ' in ingridient:
            ingridients.append(extractData(ingridient, ' pea '))
        elif ' disc ' in ingridient:
            ingridients.append(extractData(ingridient, ' disc '))
        elif ' scoop ' in ingridient:
            ingridients.append(extractData(ingridient, ' scoop '))
        elif ' unit ' in ingridient:
            ingridients.append(extractData(ingridient, ' unit '))
        elif ' cupful ' in ingridient:
            ingridients.append(extractData(ingridient, ' cupful '))
        elif 'Top up with' in ingridient:
            ingridients.append([ingridient.replace('Top up with', '').strip().lower(), 0, 'N/A'])
        else:
            ingridients.append([ingridient.strip().lower(), 0, 'N/A'])
    dat['ingridients_processed'] = ingridients
print(len(filtered_raw_data))
# Out:
# 4603

# %%
ingridient_list = {}
for dat in filtered_raw_data:
    ingridients = dat['ingridients_processed']
    for ingridient in ingridients:
        if ingridient[0] in ingridient_list:
            ingridient_list[ingridient[0]] += 1
        else:
            ingridient_list[ingridient[0]] = 1

# print(len(ingridient_list), ingridient_list)
less_than_10 = []
for ingridient, count in ingridient_list.items():
    if count < 10:
        less_than_10.append(ingridient)
print(len(less_than_10), less_than_10)
# Out:
# 444 ['tomato juice', 'worcestershire sauce', 'celery salt', 'marsala semisecco (medium)', 'mint bitters', 'blended light 3-5yo rum', 'amargo bitters', 'red grapefruit juice', 'vanilla extract', 'hot filter coffee', 'pineapple rum', 'red chili pepper', 'lemon bitters', 'orgeat almond liqueur', 'clementi antico', 'framboise eau-de-vie', 'celery gin', 'celery saccharum', 'vermouth amaro (coc.)', 'armagnac brandy', 'black walnut bitters', 'banana', 'vermouth amaro (car.)', 'clove', 'rosé/rosato vermouth', 'mezcal liqueur', 'vanilla sugar', 'pineapple (fresh)', 'apricot eau-de-vie', 'élixir végétal', 'krupnik liqueur', 'japanese whisky', 'medium dry cider', 'japanese malt whisky', 'sour cherry gin', 'dry cider', 'red grapes (seedless)', 'cold breakfast tea', 'overproof brandy', 'aged grappa', 'tiki bitters', 'pickle juice', 'corn/maize liqueur', 'mexican corn whisky', 'sauternes wine', 'robust rouge quinquina', 'papaya juice', 'yellow bell pepper', 'lactic acid solution', 'rubino/rosso/rojo vermouth', 'overproof gin', 'chai tea (cold)', 'red pineau', 'bitter honey aperitif', 'verjuice', 'mango vodka', 'spicy mango syrup', 'coriander/cilantro', 'blueberries (fresh)', 'rosemary sprig', 'strawberry jam', 'pinot noir red wine', 'cafetière coffee', 'grapefruit peel/zest', 'spanish brandy', 'rioja wine', 'chili tincture', 'blanche absinthe', 'barrel-aged bitters', 'pomegranate molasses', 'celery stick', 'white wine vinegar', 'rose sugar syrup', 'amaro (e.g. braulio)', 'mint fernet amaro', 'green food colour gel', 'freshly grated nutmeg', 'pistachio syrup', 'orinoco bitters', 'curry leaf', 'lychee/litchi syrup', 'oregano (fresh)', 'pastis', 'groseille syrup', 'sage gin', 'chili flakes', 'tonic water (salty lemon)', 'sage leaves', 'beetroot juice', 'mango juice', 'italian brandy', 'olive oil', 'coffee bitters', 'vanilla liqueur', 'pineapple and chili vodka', 'oat milk', 'matcha powder', 'marshmallow syrup', 'pineau des charentes', 'pimento bitters', 'canadian whisky', 'mandarin juice', 'raspberry jam', 'hop grapefruit bitters', 'olive brine', 'ginseng bitters', 'sugar cube', 'island single malt', 'fresh thyme', 'cocoa bitters', 'strawberry sugar syrup', 'bourbon bonded-strength', 'orange peel', 'honey', 'peach purée', 'india pale ale (ipa) beer', 'orange (fresh)', 'maraschino cherry', 'green cardamom pods', 'overproof aged light rum', 'highland malt whisky', 'cava', 'cold black tea', 'sesame oil', 'oak aged gin', 'tobacco bitters', 'cold brew coffee', 'amaro (e.g. nardini)', 'angostura di amaro', 'egg yolk', 'american single malt', 'shiraz red wine', 'pot still whiskey', 'lime zest (peel)', 'cherry tomato (fresh)', 'white balsamic', 'grapefruit gin', 'roasted coffee beans', 'fresh ginger', 'coconut syrup', 'mediterranean tonic', 'lime bitters', 'cherry juice', 'ginger wine', 'vanilla ice cream', 'kiwi fruit (fresh)', 'ruby port', 'jerry thomas bitters', 'lillet rouge', 'homemade ginger syrup', 'aromatic tonic water', 'rum 10+ year old', 'amaro (e.g. ciociaro)', 'kiwi sugar syrup', 'red curaçao liqueur', 'lemongrass stem', 'amber bitter liqueur', 'star anise', 'balsamic vinegar', 'tonka bitters', 'lemon sorbet', 'lowland malt whisky', 'banana rum', 'orange zest/swath', 'pumpkin spice syrup', 'redcurrants', 'pear vodka', 'sugar snap peas', 'sparkling water', '100% pot still rum', 'cold lapsang souchong', 'ouzo', 'vanilla pod', 'china-china liqueur', 'apple sugar syrup', 'rosé champagne', 'toffee liqueur', 'navy strength gin', 'sorrel liqueur', 'pomegranate liqueur', 'rhubarb syrup', 'blood orange liqueur', 'rhubarb bitters', 'banana (yellow) sugar syrup', 'plum bitters', 'watermelon juice', 'vanilla rum', 'stout beer', 'spiced pear liqueur', 'acqua bianca liqueur', 'spiced choc. bitters', 'fresh lemon peel', 'fresh orange peel', 'mirabelle eau-de-vie', 'umeshu plum sake', 'caramel liqueur', 'coffee vermouth', 'chilli syrup', 'coriander bitters', 'red bitter soda', 'coconut sorbet', 'grapefruit vodka', 'rhubarb liqueur', 'coconut milk', 'pach ...

# %%
MAPPING = {
    'bitter_herbal_floral': [
        'mint bitters', 'lavender bitters', 'ginseng bitters', 
        'coriander bitters', 'dandelion and burdock bitters', 'tonka bitters', 'tea bitters', 'turmeric bitters', 'liquorice bitters', 'boston bittah bitters', 'martini bitter'
    ],
    'bitter_fruit_citrus': [
        'lemon bitters', 'lime bitters', 'peach bitters', 'plum bitters',
        'rhubarb bitters', 'cherry bitters', 'cranberry bitters', 'maple bitters', 'pear bitters', 'hop grapefruit bitters'
    ],
    'bitter_spice_wood': [
        "abbott's bitters", 'orinoco bitters', 'cardamom bitters',
        'tobacco bitters', 'black walnut bitters', 'pimento bitters',
        'barrel-aged bitters', 'spiced choc. bitters'
    ],
    'bitter_chocolate_coffee': ['cocoa bitters', 'jerry thomas bitters', 'coffee bitters'],
    'bitter_generic': [
        'amargo bitters', 'tiki bitters', 'bitter honey aperitif',
        'burlesque bitters', 'olive bitters'
    ],
    'fruit_liqueurs': [
        'fruit cup liqueur',
        'cranberry liqueur',
        'red curaçao liqueur',
        'pineapple liqueur',       # Tropical fruit
        'sour apple liqueur',      # Tart fruit
        'strawberry liqueur',      # Berry fruit
        'pomegranate liqueur',     # Tart berry fruit
        'lychee liqueur',          # Tropical fruit
        'blood orange liqueur',    # Citrus fruit
        'fig liqueur',             # Sweet fruit
        'quince liqueur',          # Tart fruit
        'kumquat liqueur',         # Citrus fruit
        'blueberry liqueur',       # Berry fruit
        'lapponia cloudberry liqueur', # Berry fruit
        'green banana liqueur',    # Tropical fruit
        'pear liqueur',            # Orchard fruit
        'spiced pear liqueur'      # Fruit + spice (primarily fruit)
    ],
    'citrus_liqueurs': [
        'créole shrubb liqueur',   # Orange-based
        'yuzushu liqueur',         # Japanese citrus
        'china-china liqueur',     # Orange/bitter orange
        'agave sec liqueur'        # Agave + citrus notes
    ],
    'herbal_floral_liqueurs': [
        'génépi liqueur',          # Alpine herb (artemisia)
        'lavender liqueur',        # Floral
        'thyme liqueur',           # Herb
        'sorrel liqueur',          # Herb/tart
        'vetiver gris liqueur',    # Grassy/herbal
        'rhubarb liqueur',         # Tart botanical (not sweet fruit)
        'chamomile/camomile liqueur', # Floral/herbal
        'acqua bianca liqueur',    # Herbal Italian
        'ginseng liqueur',          # Herbal/earthy
        'jasmine liqueur',
        'myrtle/mirto liqueur',
        'everleaf forest',
        'ratafia de marseille',
        'chamberyzette aperitif'
    ],
    'nut_spice_liqueurs': [
        'orgeat almond liqueur',   # Almond (nut)
        'walnut liqueur',          # Nut
        'mastiha liqueur',         # Resin/spice
        'corn/maize liqueur',      # Grain/spice
        'krupnik liqueur',         # Honey/spice
        'pistachio cream liqueur',  # Nut + cream
        'chestnut liqueur',
        'roasted buckwheat cordial',
        'toffee liqueur',
        'elixir liqueur'
    ],
    'bitter_amaro_liqueurs': [
        'becherovka liqueur',      # Herbal bitter
        'mezcal liqueur',          # Smoky/bitter
        'amaro liqueur',           # Generic bitter
        'centerbe liqueur',        # "Hundred herbs" - bitter herbal
        'izarra jaune liqueur',    # Basque herbal bitter
        'chinotto liqueur',        # Bitter citrus
        'bitter almond liqueur',   # Bitter nut (not sweet almond)
        'pacharan liqueur',         # Basque sloe/bitter
        'amber bitter liqueur',
        'mince pie liqueur'
    ],
    'anise_liqueurs': [
        'aniseed liqueur',         # Anise
        'anisette liqueur',        # Anise
        'pastis',                  # Anise (though not in list, related)
        'ouzo'                     # Anise (though not in list, related)
    ],
    'chocolate_caramel_liqueurs': [
        'parfait amour liqueur',   # Vanilla/citrus/floral (but often chocolatey)
        'vanilla liqueur',         # Sweet vanilla
        'caramel liqueur',         # Sweet caramel
        'chocolate liqueur',       # Chocolate
        'chocolate orange liqueur',# Chocolate + citrus
        'butterscotch liqueur',    # Butterscotch
        'goldwasser liqueur',      # Spiced citrus with gold flakes
        'tuaca liqueur',           # Vanilla/citrus
        'southern liqueur',         # Often peach/vanilla (Southern Comfort style)
        'crème yvette liqueur',
        'crème brûlée syrup',
        'popcorn sugar syrup',
        'bubblegum syrup'
    ],
    'savory_unique_liqueurs': [
        'tobacco liqueur',
        'tequila agave liqueur',
        'honey liqueur',
        'coffee schnapps liqueur',
        'tomato liqueur',          # Savory vegetable
        'aloe liqueur'             # Herbal/slightly bitter
    ],
    'flavored_rum': ['pineapple rum', 'banana rum', 'cacao spiced rum', 'vanilla rum'],
    'specialty_rum': ['blended light 3-5yo rum', 'overproof aged light rum', '100% pot still rum'],

    # Group 1: Light/Delicate
    'light_delicate_whisky': ['canadian whisky', 'japanese whisky', 'japanese malt whisky', 'lowland malt whisky', 'grain whisky', 'canadian rye whisky'],

    # Group 2: Unique Grain
    'unique_grain_whisky': ['mexican corn whisky'],

    # Group 3: Scotch Malt Character  
    'scotch_malt_whisky': ['highland malt whisky', 'vatted malt whisky'],

    'rare_whiskies': ['japanese malt whisky', 'lowland malt whisky', 'grain whisky', 'canadian rye whisky'],

    'infused_flavor_gin': [
        'celery gin', 'sour cherry gin', 'sage gin', 
        'grapefruit gin', 'honey and mint gin'
    ],
    'strength_aged_gin': [
        'overproof gin', 'navy strength gin', 'oak aged gin'
    ],
    'red_wine': ['claret wine', 'pinot noir red wine', 'rioja wine', 'shiraz red wine'],
    'white_wine': ['chardonnay wine', 'viognier white wine', 'soave wine'],
    'sweet_wine': ['sauternes wine', 'moscato d\'asti wine', 'ginger wine'],
    'cider': ['medium dry cider', 'dry cider'],
    'grape_brandy': [
        'armagnac brandy',    # French grape brandy
        'spanish brandy',     # Spanish grape brandy  
        'italian brandy',     # Italian grape brandy
        'overproof brandy'    # High-proof grape brandy (typically)
    ],
    'fruit_brandy': [
        'peach brandy',           # Peach-based
        'apple/cider eau-de-vie'  # Apple-based
    ],
    'citrus_juice': [
        'red grapefruit juice',  # Bitter citrus
        'mandarin juice',        # Sweet citrus
        'citrus juice'           # Generic citrus
    ],
    'sweet_fruit_juice': [
        'papaya juice',
        'red grape juice',
        'mango juice',           # Tropical sweet
        'cherry juice',          # Berry sweet/tart
        'watermelon juice',      # Melon sweet
        'lychee juice drink',    # Tropical sweet
        'peach juice',           # Stone fruit sweet
        'sparkling apple juice'  # Apple sweet + fizz
    ],
    'vegetable_savory_juice': [
        'verjuice',
        'tomato juice',          # Savory (Bloody Mary)
        'beetroot juice',        # Earthy, sweet-savory
        'celery juice',          # Herbal, vegetal
        'carrot juice',          # Sweet-vegetal
        'red bell pepper juice'  # Sweet-vegetal
    ],
    'fruit_syrup': [
        'spicy mango syrup',        # Mango (tropical fruit)
        'lychee/litchi syrup',      # Lychee (tropical fruit)
        'groseille syrup',          # Red currant (berry fruit)
        'strawberry sugar syrup',   # Strawberry (berry fruit)
        'kiwi sugar syrup',         # Kiwi (tropical fruit)
        'apple sugar syrup',        # Apple (orchard fruit)
        'rhubarb syrup',            # Rhubarb (tart fruit)
        'cherry syrup',             # Cherry (stone fruit)
        'watermelon syrup',         # Watermelon (melon fruit)
        'pink grapefruit syrup',    # Grapefruit (citrus fruit)
        'spiced red berries syrup', # Mixed berries (berry fruit)
        'blackcurrant syrup',       # Blackcurrant (berry fruit)
        'peach syrup',              # Peach (stone fruit)
        'grapefruit syrup',
        'cranberry syrup',
        'pineapple jam',
        'raspberry jam'
    ],
    'herbal_floral_syrup': [
        'tarragon sugar syrup',
        'rosemary syrup',
        'lemongrass syrup',
        'lapsang souch. syrup',
        'elderflower cordial',
        'peppermint syrup',
        'celery saccharum',
        'lavender sugar syrup',     # Lavender (floral)
        'rose sugar syrup',         # Rose (floral)
        'cherry blossom syrup',     # Cherry blossom (floral)
        'cucumber syrup',           # Cucumber (vegetal/herbal)
        'basil syrup',              # Basil (herbal)
    ],
    'spice_syrup': [
        'chilli syrup',
        'ginger jam',
        'homemade ginger syrup',    # Ginger (spice)
        'pumpkin spice syrup',      # Pumpkin spice blend
        'gingerbread sugar syrup',  # Ginger + spices
        'winter spice syrup',       # Seasonal spice blend
        'cardamom sugar syrup',     # Cardamom (spice)
    ],
    'nut_caramel_syrup': [
        'banana (yellow) sugar syrup',
        'pistachio syrup',          # Pistachio (nut)
        'maraschino syrup',         # Marasca cherry (nutty notes)
        'caramel syrup',            # Caramel (sweet/burnt sugar)
        'hazelnut syrup',           # Hazelnut (nut)
        'coconut syrup',            # Coconut (tropical nut)
        'macadamia nut syrup',      # Macadamia (nut)
        'salted caramel syrup',     # Caramel + salt
        'marshmallow syrup',        # Vanilla/sweet (like caramel)
    ],
    'simple_syrup': [
        'barspoon powdered sugar',
        'powdered panela sugar',
        'cola syrup',
        'sugar cane syrup',         # Cane sugar
        'gomme syrup',              # Gum arabic syrup
        'sugar syrup 1:1',          # Basic simple syrup
        'honey syrup (2:1)',        # Honey-based simple
    ],
    'fresh_fruit': [
        'green grapes (seedless)', 'red grapes (seedless)', 'fresh banana', 'banana',
        'pineapple (fresh)', 'blueberries (fresh)', 'blackberries',
        'cherry tomato (fresh)', 'fresh kiwi fruit (fresh)', 'kiwi fruit (fresh)',
        'slice pineapple (fresh)', 'redcurrants', 'passion fruit purée',
        'watermelon (fresh)', 'orange (fresh)', 'figs', 'yellow bell pepper',
        'cranberries (fresh)', 'red bell pepper', 'ruby red grapefruit', 'pineapple puree',
        'fresh strawberries (fresh)', 'raisins', 'cherries (destoned)', 'strawberry puree',
        'peach purée', 'mango purée', 'raspberry puree', 'fresh peach', 'fresh lemon (fresh)', 'lemon (fresh)', '8 segment tangerine/mandarin', 'sugar snap peas'  # Vegetable but fresh
    ],
    'fresh_herbs_spices': [
        'clove', 'red chili pepper', 'coriander/cilantro', 'freshly grated nutmeg',
        'green cardamom pods', 'curry leaf', 'oregano (fresh)', 'sage leaves',
        'fresh rosemary sprig', 'fresh thyme', 'fresh dill', 'lemongrass stem',
        'fresh ginger', 'orange zest/swath', 'lime zest (peel)', 'fresh lemon peel',
        'fresh orange peel', 'orange peel', 'rosemary sprig', 'rosemary sprig',
        'thai basil leaves', 'mint (fresh) sprigs', 'slice orange (fresh)', 'celery stick',
        'grapefruit peel/zest', 'lemon peel', 'star anise', 'fennel seeds', 'vanilla pod', 'chili flakes', 'cayenne pepper', 'jalapeno slice', 'red chili pepper', 'wasabi leaf', 'black olives'
    ],
    'egg_dairy': [
        'egg white', 'egg (white and yolk)', 'egg yolk', 'fresh egg yolk', 'lemon sorbet', 'scoop lemon sorbet',
        'vanilla ice cream', 'coconut sorbet', 'raspberry sorbet', 'coconut cream',
        'coconut milk', 'yoghurt (natural)', 'mascarpone cheese', 'evaporated milk',
        'oat milk', 'fresh egg white (pasteurised)', 'fresh egg white', 'almond milk'
    ],
    'coffee_tea': [
        'hot filter coffee', 'chai tea (cold)', 'cold breakfast tea',
        'cafetière coffee', 'cold black tea', 'cold brew coffee', 'roasted coffee beans',
        'cold lapsang souchong', 'berry fruit tea (cold)', 'banana tea', 'cold espresso coffee', 'cold brew concentrate', 'cold white tea', 'rooibos tea (cold)', 'hot breakfast tea', 'peach iced tea', '10 gram ground coffee'
    ],
    'sweeteners': [
        'vanilla extract', 'vanilla sugar', 'orange marmalade', 'strawberry jam',
        'blackcurrant jam (preserve)', 'powdered sugar',
        'honey', 'honey water (1:1)', 'brown sugar', 'sugar cube',
        'pomegranate molasses', 'orange cream citrate'
    ],
    'salt_acid_savory': [
        'celery salt', 'worcestershire sauce', 'white wine vinegar',
        'balsamic vinegar', 'white balsamic', 'olive brine', 'caper brine',
        'salt', 'pinch salt', 'saline solution 10:1',
        'beef bouillon', 'white pepper (ground)', 'dijon mustard', 'wasabi paste',
        'pumpkin puree', 'pickle juice', 'pickle salt', 'soy sauce', 'citric acid (10%) solution', 'lactic acid solution', 'acidic mixer'
    ],
    'oils_vinegars': [
        'olive oil', 'sesame oil', 'lemon zest oils', 'élixir végétal'  # Herbal oil
    ],
    'beer_sparkling': [
        'india pale ale (ipa) beer', 'stout beer', 'dunkel/black lager',
        'pilsner lager', 'sparkling water', 'boiling water', 'soda from siphon',
        'coconut water', 'birch water', 'kombucha', 'celery soda',
        'tonic water (smoked)', 'mediterranean tonic', 'bitter lemon tonic',
        'aromatic tonic water', 'red bitter soda', 'cherry soda', 'lemonade',
        'pineapple soda', 'mandarin soda', 'fig leaf soda', 'banana tea soda',
        'mango soda', 'coconut-pineapple soda', 'white peach and jasmine soda',
        'elderberry and hibiscus soda', 'grape and apricot soda', 'strawberry soda',
        'olive lemonade', 'tonic water (salty lemon)', 'orange flavoured soda water', 'british bitter ale', 'belgium dubbel abbey ale', 'rhubarb soda', 'root beer', 'energy drink', 'sparkling coconut water', 'barrel aged red beer', 'ice cider', 'aegean tonic water', 'irn-bru', 'cucumber tonic water', 'pale ale', 'stout beer', '1 splash soda (club soda) water'
    ],
    'wines_fortified': [
        'palo cortado sherry', 'rosé/rosato vermouth', 'rubino/rosso/rojo vermouth',
        'white port', 'ruby port', 'marsala semisecco (medium)', 'blossom vermouth',
        'pommeau du normandie', 'orancio vino aperitif', 'lillet rouge',
        'rosé champagne', 'cava', 'pinot grigio', 'coffee vermouth', 'rosé wine', 'riesling wine', 'verdelho madeira', 'malmsey madeira', 'moscatel sherry', 'grüner veltliner wine', 'lillet rosé', 'red pineau'
    ],
    'spirits_liqueurs': [
        'aged agricole rhum', 'clementi antico', 'framboise eau-de-vie',
        'aged grappa', 'apricot eau-de-vie', 'robust rouge quinquina',
        'akvavit / aquavit', 'chili tincture', 'blanche absinthe',
        'amaro (e.g. braulio)', 'mint fernet amaro', 'chinato (barolo/barbera/grignolino)',
        'tsipouro', 'pineau des charentes', 'bourbon bonded-strength',
        'german amaro', 'angostura di amaro', 'amer picon', 'vermouth amaro (car.)',
        'vermouth amaro (coc.)', 'amaro (e.g. nardini)', 'amaro (e.g. ciociaro)',
        'underberg', 'chinotto', 'herboris amaro centerbe', 'crème de noyau',
        'amaro formidabile', 'sambuca', 'batavia arrack', 'spirit',
        'greek spirit', 'peach and orange spirit', 'grapefruit rose spirit',
        'umeshu plum sake', 'rose water', 'peach aperitif', 'mirabelle eau-de-vie', 'plum brandy', 'birch eau-de-vie', 'blanche armagnac', 'poteen/poitín', 'herbal coffee liqueur', 'liquorice liqueur', 'barrel aged genever'
    ],
    'infused_spirits': [
        'mango vodka', 'pineapple and chili vodka', 'pear vodka',
        'habenero bourbon', 'grapefruit vodka', 'rhubarb flavoured vodka',
        'orange vodka', 'lime vodka', 'cachaça (aged 3+ years)',
        'cardamom and ginger vodka', 'raspberry vodka', 'strawberry flavoured vodka',
        'watermelon flavoured vodka', 'pepper vodka', 'passion fruit vodka',
        'mixed berry flavoured vodka', 'american single malt', 'island single malt',
        'pot still whiskey', 'spiced gin', 'rum 10+ year old'
    ],
    'misc_unique': [
        'ring yellow bell pepper', 'green food colour gel', 'cocktail foamer', 'matcha powder',
        'jalapeño tequila', 'maraschino cherry', 'barspoon matcha powder', '*special ingredient #1', 'pineapple verdita', 'wht grapefruit juice'
    ],
    'artisanal_specialty': [
        'raspberry kombucha',
        'hot water',  # But this might be too generic
        'barspoon raspberry jam'  # Already in sweeteners
    ]
}

# %%
GROUPING_MAP = {}

for key, value in MAPPING.items():
    for v in value:
        GROUPING_MAP[v] = key

print(GROUPING_MAP)
# Out:
# {'mint bitters': 'bitter_herbal_floral', 'lavender bitters': 'bitter_herbal_floral', 'ginseng bitters': 'bitter_herbal_floral', 'coriander bitters': 'bitter_herbal_floral', 'dandelion and burdock bitters': 'bitter_herbal_floral', 'tonka bitters': 'bitter_herbal_floral', 'tea bitters': 'bitter_herbal_floral', 'turmeric bitters': 'bitter_herbal_floral', 'liquorice bitters': 'bitter_herbal_floral', 'boston bittah bitters': 'bitter_herbal_floral', 'martini bitter': 'bitter_herbal_floral', 'lemon bitters': 'bitter_fruit_citrus', 'lime bitters': 'bitter_fruit_citrus', 'peach bitters': 'bitter_fruit_citrus', 'plum bitters': 'bitter_fruit_citrus', 'rhubarb bitters': 'bitter_fruit_citrus', 'cherry bitters': 'bitter_fruit_citrus', 'cranberry bitters': 'bitter_fruit_citrus', 'maple bitters': 'bitter_fruit_citrus', 'pear bitters': 'bitter_fruit_citrus', 'hop grapefruit bitters': 'bitter_fruit_citrus', "abbott's bitters": 'bitter_spice_wood', 'orinoco bitters': 'bitter_spice_wood', 'cardamom bitters': 'bitter_spice_wood', 'tobacco bitters': 'bitter_spice_wood', 'black walnut bitters': 'bitter_spice_wood', 'pimento bitters': 'bitter_spice_wood', 'barrel-aged bitters': 'bitter_spice_wood', 'spiced choc. bitters': 'bitter_spice_wood', 'cocoa bitters': 'bitter_chocolate_coffee', 'jerry thomas bitters': 'bitter_chocolate_coffee', 'coffee bitters': 'bitter_chocolate_coffee', 'amargo bitters': 'bitter_generic', 'tiki bitters': 'bitter_generic', 'bitter honey aperitif': 'bitter_generic', 'burlesque bitters': 'bitter_generic', 'olive bitters': 'bitter_generic', 'fruit cup liqueur': 'fruit_liqueurs', 'cranberry liqueur': 'fruit_liqueurs', 'red curaçao liqueur': 'fruit_liqueurs', 'pineapple liqueur': 'fruit_liqueurs', 'sour apple liqueur': 'fruit_liqueurs', 'strawberry liqueur': 'fruit_liqueurs', 'pomegranate liqueur': 'fruit_liqueurs', 'lychee liqueur': 'fruit_liqueurs', 'blood orange liqueur': 'fruit_liqueurs', 'fig liqueur': 'fruit_liqueurs', 'quince liqueur': 'fruit_liqueurs', 'kumquat liqueur': 'fruit_liqueurs', 'blueberry liqueur': 'fruit_liqueurs', 'lapponia cloudberry liqueur': 'fruit_liqueurs', 'green banana liqueur': 'fruit_liqueurs', 'pear liqueur': 'fruit_liqueurs', 'spiced pear liqueur': 'fruit_liqueurs', 'créole shrubb liqueur': 'citrus_liqueurs', 'yuzushu liqueur': 'citrus_liqueurs', 'china-china liqueur': 'citrus_liqueurs', 'agave sec liqueur': 'citrus_liqueurs', 'génépi liqueur': 'herbal_floral_liqueurs', 'lavender liqueur': 'herbal_floral_liqueurs', 'thyme liqueur': 'herbal_floral_liqueurs', 'sorrel liqueur': 'herbal_floral_liqueurs', 'vetiver gris liqueur': 'herbal_floral_liqueurs', 'rhubarb liqueur': 'herbal_floral_liqueurs', 'chamomile/camomile liqueur': 'herbal_floral_liqueurs', 'acqua bianca liqueur': 'herbal_floral_liqueurs', 'ginseng liqueur': 'herbal_floral_liqueurs', 'jasmine liqueur': 'herbal_floral_liqueurs', 'myrtle/mirto liqueur': 'herbal_floral_liqueurs', 'everleaf forest': 'herbal_floral_liqueurs', 'ratafia de marseille': 'herbal_floral_liqueurs', 'chamberyzette aperitif': 'herbal_floral_liqueurs', 'orgeat almond liqueur': 'nut_spice_liqueurs', 'walnut liqueur': 'nut_spice_liqueurs', 'mastiha liqueur': 'nut_spice_liqueurs', 'corn/maize liqueur': 'nut_spice_liqueurs', 'krupnik liqueur': 'nut_spice_liqueurs', 'pistachio cream liqueur': 'nut_spice_liqueurs', 'chestnut liqueur': 'nut_spice_liqueurs', 'roasted buckwheat cordial': 'nut_spice_liqueurs', 'toffee liqueur': 'nut_spice_liqueurs', 'elixir liqueur': 'nut_spice_liqueurs', 'becherovka liqueur': 'bitter_amaro_liqueurs', 'mezcal liqueur': 'bitter_amaro_liqueurs', 'amaro liqueur': 'bitter_amaro_liqueurs', 'centerbe liqueur': 'bitter_amaro_liqueurs', 'izarra jaune liqueur': 'bitter_amaro_liqueurs', 'chinotto liqueur': 'bitter_amaro_liqueurs', 'bitter almond liqueur': 'bitter_amaro_liqueurs', 'pacharan liqueur': 'bitter_amaro_liqueurs', 'amber bitter liqueur': 'bitter_amaro_liqueurs', 'mince pie liqueur': 'bitter_amaro_liqueurs', 'aniseed liqueur': 'anise_liqueurs', 'ani ...

# %%
ingridient_list = {}
for dat in filtered_raw_data:
    ingridients = dat['ingridients_processed']
    ingridient_final = []
    for ingridient in ingridients:
        ing_name = ingridient[0]
        if ingridient[0] in GROUPING_MAP:
            ing_name = GROUPING_MAP[ingridient[0]]
        ingridient_final.append([ing_name, ingridient[1], ingridient[2]])
        if ingridient[0] in ingridient_list:
            ingridient_list[ing_name] += 1
        else:
            ingridient_list[ing_name] = 1
    dat['ingridients_final'] = ingridient_final

# print(len(ingridient_list), ingridient_list)
print(len(filtered_raw_data))
# Out:
# 4603

# %%
ingridient_list = {}
for dat in filtered_raw_data:
    ingridients = dat['ingridients_final']
    for ingridient in ingridients:
        if ingridient[0] in ingridient_list:
            ingridient_list[ingridient[0]] += 1
        else:
            ingridient_list[ingridient[0]] = 1

# print(len(ingridient_list), ingridient_list)
less_than_10 = []
for ingridient, count in ingridient_list.items():
    if count < 10 and ingridient not in MAPPING:
        less_than_10.append(ingridient)
print(len(less_than_10), less_than_10)
# Out:
# 0 []

# %%
final_data = []

for dat in filtered_raw_data:
    final_data.append({
        'ingridients': dat['ingridients_final'],
        'keywords': dat['keywords'],
        'strength_rating': dat['strength_rating'],
        'taste_rating': dat['taste_rating'],
        'rating': dat['rating']
    })

print(len(final_data), final_data)
# Out:
# 4603 [{'ingridients': [['gin', 25.0, 'ml'], ['orange curaçao', 25.0, 'ml'], ['rosso/sweet vermouth', 25.0, 'ml'], ['aromatic bitters', 2.0, 'dash'], ['ginger ale', 50.0, 'ml'], ['cola', 50.0, 'ml']], 'keywords': ['Fruity', "Pimm's Cup"], 'strength_rating': 6, 'taste_rating': 6, 'rating': 5}, {'ingridients': [['mint leaves', 7.0, 'fresh'], ['cognac (brandy)', 45.0, 'ml'], ['rye whiskey 50% abv', 15.0, 'ml'], ['brown sugar syrup', 7.5, 'ml'], ['orange bitters', 2.0, 'dash']], 'keywords': ['Savoury'], 'strength_rating': 7, 'taste_rating': 7, 'rating': 5}, {'ingridients': [['gin', 45.0, 'ml'], ['red quinquina e.g. dubonnet, byrrh', 30.0, 'ml'], ['maraschino liqueur', 7.5, 'ml'], ['red bitter liqueur', 7.5, 'ml']], 'keywords': [], 'strength_rating': 8, 'taste_rating': 8, 'rating': 5}, {'ingridients': [['gin', 60.0, 'ml'], ['vegetable_savory_juice', 120.0, 'ml'], ['lemon juice', 15.0, 'ml'], ['sugar syrup (2:1)', 7.5, 'ml'], ['salt_acid_savory', 4.0, 'dash'], ['red hot pepper sauce', 7.0, 'drop'], ['black pepper', 2.0, 'grind'], ['salt_acid_savory', 2.0, 'pinch']], 'keywords': ['Red Snapper'], 'strength_rating': 5, 'taste_rating': 7, 'rating': 5}, {'ingridients': [['blanco tequila', 60.0, 'ml'], ['bianco/blanco vermouth', 30.0, 'ml'], ['margarita bitters', 4.0, 'drop']], 'keywords': [], 'strength_rating': 9, 'taste_rating': 7, 'rating': 5}, {'ingridients': [['light gold rum 1-3yo', 25.0, 'ml'], ['orange curaçao', 25.0, 'ml'], ['rosso/sweet vermouth', 25.0, 'ml'], ['aromatic bitters', 2.0, 'dash'], ['ginger ale', 50.0, 'ml'], ['cola', 50.0, 'ml']], 'keywords': ['Fruity', 'Tiki/tropical'], 'strength_rating': 6, 'taste_rating': 6, 'rating': 5}, {'ingridients': [['gin', 50.0, 'ml'], ['wines_fortified', 10.0, 'ml'], ['amaretto liqueur', 7.5, 'ml'], ['dry vermouth', 5.0, 'ml'], ["boker's bitters", 1.0, 'dash']], 'keywords': [], 'strength_rating': 9, 'taste_rating': 7, 'rating': 5}, {'ingridients': [['gin', 45.0, 'ml'], ['ferro china', 30.0, 'ml'], ['rosso/sweet vermouth', 30.0, 'ml'], ['bitter_herbal_floral', 4.0, 'drop']], 'keywords': ['Bittersweet'], 'strength_rating': 7, 'taste_rating': 7, 'rating': 5}, {'ingridients': [['light gold rum 1-3yo', 30.0, 'ml'], ['specialty_rum', 15.0, 'ml'], ['cachaça', 5.0, 'ml'], ['lime juice', 15.0, 'ml'], ['sweeteners', 2.0, 'barspoon'], ['daiquiri bitters', 4.0, 'drop']], 'keywords': [], 'strength_rating': 7, 'taste_rating': 6, 'rating': 5}, {'ingridients': [['rye whiskey 50% abv', 25.0, 'ml'], ['orange curaçao', 25.0, 'ml'], ['rosso/sweet vermouth', 25.0, 'ml'], ['aromatic bitters', 2.0, 'dash'], ['ginger ale', 50.0, 'ml'], ['cola', 50.0, 'ml']], 'keywords': ['Fruity'], 'strength_rating': 6, 'taste_rating': 6, 'rating': 5}, {'ingridients': [['calvados apple brandy', 25.0, 'ml'], ['orange curaçao', 25.0, 'ml'], ['rosso/sweet vermouth', 25.0, 'ml'], ['aromatic bitters', 2.0, 'dash'], ['ginger ale', 50.0, 'ml'], ['cola', 50.0, 'ml']], 'keywords': ['Fruity'], 'strength_rating': 6, 'taste_rating': 6, 'rating': 5}, {'ingridients': [['scotch whisky', 25.0, 'ml'], ['orange curaçao', 25.0, 'ml'], ['rosso/sweet vermouth', 25.0, 'ml'], ['aromatic bitters', 2.0, 'dash'], ['ginger ale', 50.0, 'ml'], ['cola', 50.0, 'ml']], 'keywords': ['Fruity'], 'strength_rating': 6, 'taste_rating': 6, 'rating': 5}, {'ingridients': [['mezcal', 25.0, 'ml'], ['orange curaçao', 25.0, 'ml'], ['rosso/sweet vermouth', 25.0, 'ml'], ['bitter_herbal_floral', 2.0, 'dash'], ['ginger ale', 50.0, 'ml'], ['cola', 50.0, 'ml']], 'keywords': ['Fruity'], 'strength_rating': 6, 'taste_rating': 6, 'rating': 5}, {'ingridients': [['pisco', 25.0, 'ml'], ['orange curaçao', 25.0, 'ml'], ['rosso/sweet vermouth', 25.0, 'ml'], ['bitter_generic', 2.0, 'dash'], ['ginger ale', 50.0, 'ml'], ['cola', 50.0, 'ml']], 'keywords': ['Fruity'], 'strength_rating': 6, 'taste_rating': 6, 'rating': 5}, {'ingridients': [['gin', 62.5, 'ml'], ['dry vermouth', 12.5, 'ml'], ['chilled water', 20.0, 'ml'], ['saline solution 4:1', 2.0, 'drop']], 'keywords': ['Pre-batched'], 'streng ...

# %%
keywordMap = {
    'bittersweet': 'bittersweet',
    'citrusy': 'citrus',
    'sours (citrus)': 'citrus',
    'creamy': 'creamy',
    'dessert cocktails': 'sweet',
    'floral': 'floral',
    'fruitini': 'fruity',
    'fruity': 'fruity',
    'herbal': 'herbal',
    'nutty': 'nutty',
    'savoury': 'savoury',
    'spicy': 'spicy',
    'tiki/tropical': 'fruity'
}

# %%
ing_unit_map = {}
for dat in final_data:
    total = 0
    processed_ingridients = []
    processed_keywords = set()
    for keyword in dat['keywords']:
        if keyword.lower() in keywordMap:
            processed_keywords.add(keywordMap[keyword.lower()])
    for ingridient in dat['ingridients']:
        total += ingridient[1]
        if ingridient[0] not in ing_unit_map:
            ing_unit_map[ingridient[0]] = ingridient[2]
    for ingridient in dat['ingridients']:
        ing_name = ingridient[0].strip().lower().replace(' ', '_')
        ing_pct = (ingridient[1] / total) * 100
        processed_ingridients.append([ing_name, ing_pct])
    dat['pct_ingridients'] = processed_ingridients
    dat['processed_keywords'] = list(processed_keywords)
    # print(processed_ingridients)
print(ing_unit_map)
print(len(ing_unit_map))
# Out:
# {'gin': 'ml', 'orange curaçao': 'ml', 'rosso/sweet vermouth': 'ml', 'aromatic bitters': 'dash', 'ginger ale': 'ml', 'cola': 'ml', 'mint leaves': 'fresh', 'cognac (brandy)': 'ml', 'rye whiskey 50% abv': 'ml', 'brown sugar syrup': 'ml', 'orange bitters': 'dash', 'red quinquina e.g. dubonnet, byrrh': 'ml', 'maraschino liqueur': 'ml', 'red bitter liqueur': 'ml', 'vegetable_savory_juice': 'ml', 'lemon juice': 'ml', 'sugar syrup (2:1)': 'ml', 'salt_acid_savory': 'dash', 'red hot pepper sauce': 'drop', 'black pepper': 'grind', 'blanco tequila': 'ml', 'bianco/blanco vermouth': 'ml', 'margarita bitters': 'drop', 'light gold rum 1-3yo': 'ml', 'wines_fortified': 'ml', 'amaretto liqueur': 'ml', 'dry vermouth': 'ml', "boker's bitters": 'dash', 'ferro china': 'ml', 'bitter_herbal_floral': 'drop', 'specialty_rum': 'ml', 'cachaça': 'ml', 'lime juice': 'ml', 'sweeteners': 'barspoon', 'daiquiri bitters': 'drop', 'calvados apple brandy': 'ml', 'scotch whisky': 'ml', 'mezcal': 'ml', 'pisco': 'ml', 'bitter_generic': 'dash', 'chilled water': 'ml', 'saline solution 4:1': 'drop', 'vodka': 'ml', 'sake': 'ml', 'orange juice': 'ml', 'bourbon whiskey': 'ml', 'amaro (e.g.  nonino)': 'ml', 'orange-red aperitivo': 'ml', 'bénédictine d.o.m.': 'ml', 'creole bitters': 'dash', 'egg white (pasteurised)': 'ml', 'espresso coffee (hot)': 'ml', 'coffee liqueur': 'ml', 'fresh_fruit': 'fresh', 'soda (club soda) water': 'ml', 'cherry brandy': 'ml', 'triple sec': 'ml', 'pineapple juice': 'ml', 'grenadine syrup': 'ml', 'chartreuse green': 'ml', 'lime (fresh)': 'fresh', 'absinthe': 'ml', 'reposado tequila': 'ml', 'agave syrup': 'ml', 'aged rum (6-10yr)': 'ml', 'falernum liqueur': 'ml', 'orgeat syrup': 'ml', 'bitter_spice_wood': 'drop', 'elderflower liqueur': 'ml', 'citrus_juice': 'ml', 'old tom gin': 'ml', 'orange flower water': 'ml', 'egg_dairy': 'ml', 'whipping cream': 'ml', 'aged jamaican rum': 'ml', 'ginger liqueur': 'ml', 'pimento dram': 'ml', 'irish whiskey': 'ml', 'coffee_tea': 'ml', 'heavy/double cream': 'ml', 'flavored_rum': 'ml', 'white crème de menthe': 'ml', 'fresh_herbs_spices': 'slice', 'lime cordial': 'ml', 'oude genever': 'ml', 'spirits_liqueurs': 'ml', 'honey and water syrup': 'ml', 'white overproof rum': 'ml', 'vermouth alla vaniglia': 'ml', 'herbal_floral_syrup': 'ml', 'bitter_amaro_liqueurs': 'ml', 'sloe gin liqueur': 'ml', 'gentian liqueur': 'ml', 'americano bianco': 'ml', 'herbal_floral_liqueurs': 'ml', 'bitter_fruit_citrus': 'dash', 'vanilla bitters': 'drop', 'light white rum': 'ml', 'brut sparkling wine': 'ml', 'tonic water': 'ml', 'fruit_liqueurs': 'ml', 'dark/black rum': 'ml', 'nut_spice_liqueurs': 'ml', 'amaro (e.g. meletti)': 'ml', 'blanc quinquina/kina': 'ml', 'xocolatl mole bitters': 'dash', 'tennessee whiskey': 'ml', 'ambrato vermouth': 'ml', 'infused_flavor_gin': 'ml', 'fernet liqueur': 'ml', 'pink grapefruit juice': 'ml', 'maple syrup': 'ml', 'amaro (e.g. montenegro)': 'ml', 'grand marnier': 'ml', 'aromatized wine': 'ml', 'white crème de cacao': 'ml', 'ginger syrup': 'ml', 'cream of coconut': 'ml', 'xanthan gum (e415)': 'barspoon', 'dark crème de cacao': 'ml', 'chartreuse yellow': 'ml', 'tawny port': 'ml', 'prosecco': 'ml', 'amontillado sherry': 'ml', 'amaro (e.g. ramazzotti)': 'ml', 'fino sherry': 'ml', 'navy rum (ideally 54.5% alc./vol.)': 'ml', 'cranberry juice': 'ml', 'simple_syrup': 'ml', 'añejo tequila': 'ml', 'vermouth amaro (pun.)': 'ml', 'apricot liqueur': 'ml', 'strega liqueur': 'ml', 'grapefruit bitters': 'drop', 'grape_brandy': 'ml', 'nut_caramel_syrup': 'ml', 'amaro (e.g. averna)': 'ml', 'crème de violette': 'ml', 'blood orange juice': 'ml', 'mandarin liqueur': 'ml', 'cynar/carciofo amaro': 'ml', 'peated malt whisky': 'ml', 'speyside single malt': 'ml', 'manzanilla sherry': 'ml', 'sauvignon blanc wine': 'ml', 'chocolate_caramel_liqueurs': 'ml', 'agricole rhum (unaged)': 'ml', 'cinnamon syrup': 'ml', 'rosolio bergamotto': 'ml', 'chocolate bitters': 'drop', 'superfine/caster sugar': 'barspoon', 'pamplemousse liqueur': 'ml', 'oil ...
# 240

# %%
ckt = 0
for recipe in final_data:
    if 'processed_keywords' in recipe and len(recipe['processed_keywords']) > 0:
        ckt += 1

print(ckt)
# Out:
# 2700

# %%
all_keywords = sorted(set(
    keyword for recipe in final_data
    for keyword in recipe["processed_keywords"]
))

print(all_keywords)
# Out:
# ['bittersweet', 'citrus', 'creamy', 'floral', 'fruity', 'herbal', 'nutty', 'savoury', 'spicy', 'sweet']

# %%
all_ingredients = sorted(set(
    ing_name for recipe in final_data 
    for ing_name, _ in recipe["pct_ingridients"]
))

all_keywords = sorted(set(
    keyword for recipe in final_data
    for keyword in recipe["processed_keywords"]
))

print(len(all_ingredients))
print(len(all_keywords), all_keywords)

header = ['recipe_id']

for ing in all_ingredients:
    header.append(f'{ing}_pct')
for key in all_keywords:
    header.append(key)
header.extend(['strength_rating', 'taste_rating', 'rating'])

with open("cocktail_dataset_2700.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=header)
    writer.writeheader()
    
    for i, recipe in enumerate(final_data):
        # Initialize row with recipe ID
        row = {"recipe_id": i + 1}
        
        # A. Initialize ALL ingredient columns to 0.0
        for ing in all_ingredients:
            row[f"{ing}_pct"] = 0.0
        
        # B. Fill actual ingredient percentages (with cleaned names)
        for ing_name, pct in recipe["pct_ingridients"]:
            row[f"{ing_name}_pct"] = round(pct, 4)
        
        # C. Initialize ALL category columns to 0
        for category in all_keywords:
            row[category] = 0
        
        for category in recipe["processed_keywords"]:
            row[category] = 1
        
        # E. Add rating columns
        row["strength_rating"] = recipe.get("strength_rating", 0)
        row["taste_rating"] = recipe.get("taste_rating", 0)
        row["rating"] = recipe.get("rating", 0)
        
        if len(recipe["processed_keywords"]) > 0:
            writer.writerow(row)

print(f"CSV created successfully!")
print(f"Total recipes: {len(final_data)}")
print(f"Total ingredients: {len(all_ingredients)}")
print(f"Total columns: {len(header)}")
print(f"File saved: cocktail_dataset_normalized.csv")
# Out:
# 240
# 10 ['bittersweet', 'citrus', 'creamy', 'floral', 'fruity', 'herbal', 'nutty', 'savoury', 'spicy', 'sweet']
# CSV created successfully!
# Total recipes: 4603
# Total ingredients: 240
# Total columns: 254
# File saved: cocktail_dataset_normalized.csv
